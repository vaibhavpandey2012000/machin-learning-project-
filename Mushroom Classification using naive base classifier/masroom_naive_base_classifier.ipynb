# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('mushrooms.csv')
print(df.shape)
# Out:
# (8124, 23)

# %%
df.head(n=10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
le=LabelEncoder()
#apply transformation eack coloum
ds=df.apply(le.fit_transform)

# %%
ds.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
data=ds.values
print(data.shape)
print(type(data))
print(data[:5,:])
data_y=data[:,0]
data_x=data[:,1:]
# Out:
# (8124, 23)
# <class 'numpy.ndarray'>
# [[1 5 2 4 1 6 1 0 1 4 0 3 2 2 7 7 0 2 1 4 2 3 5]
#  [0 5 2 9 1 0 1 0 0 4 0 2 2 2 7 7 0 2 1 4 3 2 1]
#  [0 0 2 8 1 3 1 0 0 5 0 2 2 2 7 7 0 2 1 4 3 2 3]
#  [1 5 3 8 1 6 1 0 1 5 0 3 2 2 7 7 0 2 1 4 2 3 5]
#  [0 5 2 3 0 5 1 1 0 4 1 3 2 2 7 7 0 2 1 0 3 0 1]]

# %%
#break data into train and test

# %%
x_train,x_test,y_train,y_test=train_test_split(data_x,data_y,test_size=0.2)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (6499, 22) (6499,)
# (1625, 22) (1625,)

# %%
np.unique(y_train)
# Out:
# array([0, 1])

# %% [markdown]
# # Bulding Our Classifier!

# %%
def prior_prob(y_train,label):
    total_ex=y_train.shape[0]
    class_ex=np.sum(y_train==label)
    return (class_ex)/float(total_ex)

# %%
def cond_prob(x_train,y_train,feature_col,feature_val,label):
    x_fealtered=x_train[y_train==label] #its give use the all row witch crosponding colom is lable
    num=np.sum(x_fealtered[:,feature_col]==feature_val) # in all x_fealtered select those whose feature_val matched
    denom=np.sum(y_train==label)
    
    return num/float(denom)

# %% [markdown]
# # predicition

# %%
def predict(x_train,y_train,xtest):
    """here xtest is single testing point ,n feature"""
    classes=np.unique(y_train)
    n_feature=x_train.shape[1]
    post_probs=[] #List of probiblity for all classes and a given single testing point
    #compute post_probs for every class
    for label in classes:
        #post_c=lickhood*prior
        likehood=1.0
        for f in range(n_feature):
            cond=cond_prob(x_train,y_train,f,xtest[f],label)
            likehood*=cond
        prior=prior_prob(y_train,label)
        post=likehood*prior
        post_probs.append(post)
    pred=np.argmax(post_probs)
    return pred

# %%
output=predict(x_train,y_train,x_test[0])

# %%
output
# Out:
# 0

# %%
y_test[0]
# Out:
# 0

# %%
output=predict(x_train,y_train,x_test[1])
print(output,y_test[1])
# Out:
# 1 1

# %%
def score(x_train,y_train,x_test,y_test):
    pred=[]
    for i in range(x_test.shape[0]):
        pred_lable=predict(x_train,y_train,x_test[i])
        pred.append(pred_lable)
    pred=np.array(pred)
    acc=np.sum(pred==y_test)/y_test.shape[0]
    return acc

# %%
print(score(x_train,y_train,x_test,y_test))
# Out:
# 0.9987692307692307
